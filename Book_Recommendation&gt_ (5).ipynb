# %% [markdown]
# ##  Book Recommendation

# %% [markdown]
# # Business Objective:
#
# Generate the features from the dataset and use them to recommend the book
# accordingly to t useress.

# %% [markdown]
# # Content
#
# **The Book-Crossing dataset comprises 3 files.**
#
# * **Users-**
# Contains the users. Note that user IDs (User-ID) have been anonymized and map to integers.
# Demographic data is provided (Location, Age) if available. Otherwise, these fields contain NULL
# valu
#
# * **Books-** Books are identified by their respective ISBN. Invalid ISBNs have already been removed from the
# dataset. Moreover, some content-based information is given (Book-Title, Book-Author, Year
# Of-Publication, Publisher), obtained from Amazon Web Services. Note that in case of several
# authors, only the first is provided. URLs linking to cover images are also given, appearing in thee
# different flavours (Image-URL-S, Image-URL-M, Image-URL-L), i.e., small, medium, large. Tese
# URLs point to the Amazon web
#
# * **Ratings-** Contains the book rating information. Ratings (Book-Rating) are either explicit, expressed on a
# scale from 1-10 (higher values denoting higher appreciation), or implicit, expressed by 0.site.
# es.

# %%
# Importing requred  libries 
import pandas as pd 
import  numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from sklearn.feature_extraction.text import TfidfVectorizer
from PIL import Image
import requests
import re

# %%
books = pd.read_csv("C:\\Users\\Vikra\\Downloads\\dataset\\Books.csv", encoding = 'ISO-8859-1')
rating=pd.read_csv("C:\\Users\\Vikra\\Downloads\\dataset (2)\\Ratings.csv", encoding = 'ISO-8859-1')
users = pd.read_csv("C:\\Users\\Vikra\\Downloads\\dataset (2)\\Users.csv", encoding = 'ISO-8859-1')

# %%
books
# Out:
#               ISBN                                         Book-Title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358  0192126040                        Republic (World's Classics)
# 271359  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                  Book-Author Year-Of-Publication  \
# 0         Mark P. O. Morford                2002
# ...

# %%
rating
# Out:
#          User-ID         ISBN  Book-Rating
# 0         276725   034545104X            0
# 1         276726   0155061224            5
# 2         276727   0446520802            0
# 3         276729   052165615X            3
# 4         276729   0521795028            6
# ...          ...          ...          ...
# 1149775   276704   1563526298            9
# 1149776   276706   0679447156            0
# 1149777   276709   0515107662           10
# 1149778   276721   0590442449           10
# 1149779   276723  05162443314            8
#
# [1149780 rows x 3 columns]

# %%
users
# Out:
#         User-ID                            Location   Age
# 0             1                  nyc, new york, usa   NaN
# 1             2           stockton, california, usa  18.0
# 2             3     moscow, yukon territory, russia   NaN
# 3             4           porto, v.n.gaia, portugal  17.0
# 4             5  farnborough, hants, united kingdom   NaN
# ...         ...                                 ...   ...
# 278853   278854               portland, oregon, usa   NaN
# 278854   278855  tacoma, washington, united kingdom  50.0
# 278855   278856           brampton, ontario, canada   NaN
# 278856   278857           knoxville, tennessee, usa   NaN
# 278857   278858                dublin, n/a, ireland   NaN
#
# [278858 rows x 3 columns]

# %%
print("Books Shape: " ,books.shape )
print("Ratings Shape: " ,rating.shape )
print("Users Shape: " ,users.shape )
# Out:
# Books Shape:  (271360, 8)
# Ratings Shape:  (1149780, 3)
# Users Shape:  (278858, 3)

# %%
books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271360 entries, 0 to 271359
# Data columns (total 8 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ISBN                 271360 non-null  object
#  1   Book-Title           271360 non-null  object
#  2   Book-Author          271358 non-null  object
#  3   Year-Of-Publication  271360 non-null  object
#  4   Publisher            271358 non-null  object
#  5   Image-URL-S          271360 non-null  object
#  6   Image-URL-M          271360 non-null  object
#  7   Image-URL-L          271357 non-null  object
# dtypes: object(8)
# memory usage: 16.6+ MB

# %%
rating.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1149780 entries, 0 to 1149779
# Data columns (total 3 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   User-ID      1149780 non-null  int64
#  1   ISBN         1149780 non-null  object
#  2   Book-Rating  1149780 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 26.3+ MB

# %%
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 278858 entries, 0 to 278857
# Data columns (total 3 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   User-ID   278858 non-null  int64
#  1   Location  278858 non-null  object
#  2   Age       168096 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 6.4+ MB

# %%
print("Any null values in Books:\n" ,books.isnull().sum())
print('='*30)
print("Any null values in Ratings:\n ",rating.isnull().sum())
print('='*30)
print("Any null values in Users:\n",users.isnull().sum())
# Out:
# Any null values in Books:
#  ISBN                   0
# Book-Title             0
# Book-Author            2
# Year-Of-Publication    0
# Publisher              2
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            3
# dtype: int64
# ...
# Any null values in Ratings:
#   User-ID        0
# ISBN           0
# Book-Rating    0
# dtype: int64
# ...
# Any null values in Users:
#  User-ID          0
# Location         0
# Age         110762
# dtype: int64

# %%
# find the null values 
round(100*(users.isnull().sum()/len(users.index)),2)
# Out:
# User-ID      0.00
# Location     0.00
# Age         39.72
# dtype: float64

# %%
# remove the age column
users['Age'].fillna(users['Age'].median(), inplace=True)

# %%
books.duplicated().sum()
# Out:
# 0

# %%
rating.duplicated().sum()
# Out:
# 0

# %%
users.duplicated().sum()
# Out:
# 0

# %%
books.describe()
# Out:
#               ISBN      Book-Title      Book-Author  Year-Of-Publication  \
# count       271360          271360           271358               271360
# unique      271360          242135           102022                  202
# top     0195153448  Selected Poems  Agatha Christie                 2002
# freq             1              27              632                13903
#
#         Publisher                                        Image-URL-S  \
# count      271358                                             271360
# unique      16807                                             271044
# top     Harlequin  http://images.amazon.com/images/P/185326119X.0...
# freq         7535                                                  2
#
#                                               Image-URL-M  \
# count                                              271360
# unique                                             271044
# top     http://images.amazon.com/images/P/185326119X.0...
# ...

# %%
users.describe()
# Out:
#             User-ID            Age
# count  278858.00000  278858.000000
# mean   139429.50000      33.658568
# std     80499.51502      11.282618
# min         1.00000       0.000000
# 25%     69715.25000      29.000000
# 50%    139429.50000      32.000000
# 75%    209143.75000      35.000000
# max    278858.00000     244.000000

# %%
rating.describe()
# Out:
#             User-ID   Book-Rating
# count  1.149780e+06  1.149780e+06
# mean   1.403864e+05  2.866950e+00
# std    8.056228e+04  3.854184e+00
# min    2.000000e+00  0.000000e+00
# 25%    7.034500e+04  0.000000e+00
# 50%    1.410100e+05  0.000000e+00
# 75%    2.110280e+05  7.000000e+00
# max    2.788540e+05  1.000000e+01

# %%
books['Year-Of-Publication'].value_counts().index.values
# Out:
# array([2002, 2001, 1999, 2000, 1998, 2003, 1997, 1996, 1995, 1994, 1993,
#        1992, 1991, 1990, 1989, 1988, 1987, 2004, 1986, '1999', 1985,
#        '2000', '2002', '1998', '2001', 1984, 0, '1997', '1996', 1983,
#        '1995', 1982, '1994', '2003', '1993', '1992', '1991', 1981, '1990',
#        '1989', '1988', 1980, '1987', '1986', 1979, 1978, '1985', 1977,
#        '1984', '2004', '1983', 1976, '1982', '0', '1981', 1975, '1980',
#        1974, '1979', 1973, '1978', 1972, '1977', '1976', '1975', 1971,
#        '1974', 1970, '1973', 1969, '1972', '1971', 1968, '1970', 1967,
#        1966, 1965, 1964, '1969', 1963, 1960, 1961, 1962, 1959, '1968',
#        1958, 1957, '1965', 1953, 1954, 1955, '1960', 1956, '1961', '1966',
#        '1962', '1967', '1964', '1963', 1951, '1956', 2005, 1940, '1959',
#        1920, '1955', '1957', 1950, 1952, '1958', '2005', '1953', 1942,
#        1930, 1946, '1952', 1947, 1911, '1950', '1911', 1949, '1951',
# ...

# %%
# top 10 Publisher
books['Publisher'].value_counts().head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='Publisher'>

# %%
rating['Book-Rating'].value_counts().plot(kind='bar');

# %%
users['Location'] = users['Location'].apply(lambda x:x.split(',')[-1])

# %%
# top 10 user location 
users['Location'].value_counts().head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='Location'>

# %% [markdown]
# # **POPULARITY BASED RECOMMENDATION SYSTEM**
#
# * Popularity based recommendation systems are based on the rating of items by all the users.
# * Popularity based recommendation systems works with the trend. It basically uses the items which are in trend right now.

# %%
ratings_with_name = rating.merge(books,on='ISBN')

# %%
num_rating = ratings_with_name.groupby('Book-Title').count()['Book-Rating'].reset_index()
num_rating.rename(columns={'Book-Rating':'num_ratings'},inplace=True)
num_rating
# Out:
#                                                Book-Title  num_ratings
# 0        A Light in the Storm: The Civil War Diary of ...            4
# 1                                   Always Have Popsicles            1
# 2                    Apple Magic (The Collector's series)            1
# 3        Ask Lily (Young Women of Faith: Lily Series, ...            1
# 4        Beyond IBM: Leadership Marketing and Finance ...            1
# ...                                                   ...          ...
# 241066                                      Ã?Â?lpiraten.            2
# 241067                     Ã?Â?rger mit Produkt X. Roman.            4
# 241068                                Ã?Â?sterlich leben.            1
# 241069                              Ã?Â?stlich der Berge.            3
# 241070                                  Ã?Â?thique en toc            2
#
# [241071 rows x 2 columns]

# %%
avg_rating = ratings_with_name.groupby('Book-Title')['Book-Rating'].mean().reset_index()
avg_rating.rename(columns={'Book-Rating': 'avg_rating'}, inplace=True)
avg_rating
# Out:
#                                                Book-Title  avg_rating
# 0        A Light in the Storm: The Civil War Diary of ...    2.250000
# 1                                   Always Have Popsicles    0.000000
# 2                    Apple Magic (The Collector's series)    0.000000
# 3        Ask Lily (Young Women of Faith: Lily Series, ...    8.000000
# 4        Beyond IBM: Leadership Marketing and Finance ...    0.000000
# ...                                                   ...         ...
# 241066                                      Ã?Â?lpiraten.    0.000000
# 241067                     Ã?Â?rger mit Produkt X. Roman.    5.250000
# 241068                                Ã?Â?sterlich leben.    7.000000
# 241069                              Ã?Â?stlich der Berge.    2.666667
# 241070                                  Ã?Â?thique en toc    4.000000
#
# [241071 rows x 2 columns]

# %%
popular_df = num_rating.merge(avg_rating,on='Book-Title')
popular_df
# Out:
#                                                Book-Title  num_ratings  \
# 0        A Light in the Storm: The Civil War Diary of ...            4
# 1                                   Always Have Popsicles            1
# 2                    Apple Magic (The Collector's series)            1
# 3        Ask Lily (Young Women of Faith: Lily Series, ...            1
# 4        Beyond IBM: Leadership Marketing and Finance ...            1
# ...                                                   ...          ...
# 241066                                      Ã?Â?lpiraten.            2
# 241067                     Ã?Â?rger mit Produkt X. Roman.            4
# 241068                                Ã?Â?sterlich leben.            1
# 241069                              Ã?Â?stlich der Berge.            3
# 241070                                  Ã?Â?thique en toc            2
#
#         avg_rating
# 0         2.250000
# 1         0.000000
# 2         0.000000
# 3         8.000000
# ...

# %%
popular_df = popular_df[popular_df['num_ratings']>=250].sort_values('avg_rating',ascending=False).head(50)
popular_df
# Out:
#                                                Book-Title  num_ratings  \
# 80434   Harry Potter and the Prisoner of Azkaban (Book 3)          428
# 80422        Harry Potter and the Goblet of Fire (Book 4)          387
# 80441      Harry Potter and the Sorcerer's Stone (Book 1)          278
# 80426   Harry Potter and the Order of the Phoenix (Boo...          347
# 80414    Harry Potter and the Chamber of Secrets (Book 2)          556
# 191612  The Hobbit : The Enchanting Prelude to The Lor...          281
# 187377  The Fellowship of the Ring (The Lord of the Ri...          368
# 80445   Harry Potter and the Sorcerer's Stone (Harry P...          575
# 211384     The Two Towers (The Lord of the Rings, Part 2)          260
# 219741                              To Kill a Mockingbird          510
# 183573                                  The Da Vinci Code          898
# 187880                 The Five People You Meet in Heaven          430
# ...

# %%
popular_df = popular_df.merge(books,on='Book-Title').drop_duplicates('Book-Title')[['Book-Title','Book-Author','Image-URL-M','num_ratings','avg_rating']]

# %%
popular_df
# Out:
#                                             Book-Title  \
# 0    Harry Potter and the Prisoner of Azkaban (Book 3)
# 3         Harry Potter and the Goblet of Fire (Book 4)
# 5       Harry Potter and the Sorcerer's Stone (Book 1)
# 9    Harry Potter and the Order of the Phoenix (Boo...
# 13    Harry Potter and the Chamber of Secrets (Book 2)
# 16   The Hobbit : The Enchanting Prelude to The Lor...
# 17   The Fellowship of the Ring (The Lord of the Ri...
# 26   Harry Potter and the Sorcerer's Stone (Harry P...
# 28      The Two Towers (The Lord of the Rings, Part 2)
# 39                               To Kill a Mockingbird
# 47                                   The Da Vinci Code
# 53                  The Five People You Meet in Heaven
# 55                              The Catcher in the Rye
# 62                           The Lovely Bones: A Novel
# 63                                                1984
# 72                            Prodigal Summer: A Novel
# ...

# %%
popular_df['Image-URL-M'][0]
# Out:
# 'http://images.amazon.com/images/P/0439136350.01.MZZZZZZZ.jpg'

# %% [markdown]
#  # Collaborative Filtering Based Recommender System

# %%
x = ratings_with_name.groupby('User-ID').count()['Book-Rating'] > 200
users = x[x].index
users
# Out:
# Index([   254,   2276,   2766,   2977,   3363,   4017,   4385,   6251,   6323,
#          6543,
#        ...
#        271705, 273979, 274004, 274061, 274301, 274308, 275970, 277427, 277639,
#        278418],
#       dtype='int64', name='User-ID', length=811)

# %%
# filtered_rating = ratings_with_name[ratings_with_name['User-ID'].isin(padhe_likhe_users)]
filtered_rating = ratings_with_name[ratings_with_name['User-ID'].isin(users)]
filtered_rating
# Out:
#          User-ID        ISBN  Book-Rating  \
# 2           6543  034545104X            0
# 5          23768  034545104X            0
# 7          28523  034545104X            0
# 15         77940  034545104X            0
# 16         81977  034545104X            0
# ...          ...         ...          ...
# 1030883   275970  1880837927            0
# 1030884   275970  188717897X            0
# 1030885   275970  1888889047            0
# 1030886   275970  1931868123            0
# 1030887   275970  3411086211           10
#
#                                                 Book-Title  \
# 2                                     Flesh Tones: A Novel
# 5                                     Flesh Tones: A Novel
# 7                                     Flesh Tones: A Novel
# 15                                    Flesh Tones: A Novel
# 16                                    Flesh Tones: A Novel
# ...                                                    ...
# ...

# %%
y = filtered_rating.groupby('Book-Title').count()['Book-Rating']>=50
famous_books =y[y].index

# %%
final_rating = filtered_rating[filtered_rating['Book-Title'].isin(famous_books)]

# %%
pt = final_rating.pivot_table(index='Book-Title',columns='User-ID',values='Book-Rating')

# %%
pt
# Out:
# User-ID                                             254     2276    2766    \
# Book-Title
# 1984                                                   9.0     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN    10.0     NaN
# 4 Blondes                                              NaN     NaN     NaN
# A Bend in the Road                                     0.0     NaN     7.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        NaN     NaN     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# ...

# %%
pt.fillna(0 , inplace= True)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity_scores = cosine_similarity(pt)

# %%
similarity_scores.shape
# Out:
# (706, 706)

# %%
def recommend(book_name):
    # index fetch
    index = np.where(pt.index==book_name)[0][0]
    similar_items = sorted(list(enumerate(similarity_scores[index])),key=lambda x:x[1],reverse=True)[1:5]
    
    data = []
    for i in similar_items:
        item = []
        temp_df = books[books['Book-Title'] == pt.index[i[0]]]
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Title'].values))
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Author'].values))
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Image-URL-M'].values))
        
        data.append(item)
    
    return data

# %%
recommend('1984')
# Out:
# [['Animal Farm',
#   'George Orwell',
#   'http://images.amazon.com/images/P/0451526341.01.MZZZZZZZ.jpg'],
#  ["The Handmaid's Tale",
#   'Margaret Atwood',
#   'http://images.amazon.com/images/P/0449212602.01.MZZZZZZZ.jpg'],
#  ['Brave New World',
#   'Aldous Huxley',
#   'http://images.amazon.com/images/P/0060809833.01.MZZZZZZZ.jpg'],
#  ['The Vampire Lestat (Vampire Chronicles, Book II)',
#   'ANNE RICE',
#   'http://images.amazon.com/images/P/0345313860.01.MZZZZZZZ.jpg']]

# %%
book = rating.merge(books, on ="ISBN" )
book

# %%
# Reduce dataset for content similarity by selecting top-rated books
# Keep books with an average rating above a certain threshold

# Calculate average rating for each book
book_avg_rating = ratings_filtered.groupby('ISBN')['Book-Rating'].mean()
highly_rated_books = book_avg_rating[book_avg_rating >= 4].index
highly_rated_data = merged_data[merged_data['ISBN'].isin(highly_rated_books)]

# Re-create the TF-IDF matrix on this smaller subset
tfidf_matrix = tfidf.fit_transform(highly_rated_data['content'])

# Approximate nearest neighbors for cosine similarity in the reduced data
approx_knn = NearestNeighbors(metric='cosine', algorithm='brute')
approx_knn.fit(tfidf_matrix)

# Revised hybrid recommendation function using approximate content similarity
def hybrid_recommend_v2(user_id, isbn, num_recommendations=5):
    # Content-based recommendations using approximate similarity
    if isbn in highly_rated_data['ISBN'].values:
        book_idx = highly_rated_data[highly_rated_data['ISBN'] == isbn].index[0]
        distances, indices = approx_knn.kneighbors(tfidf_matrix[book_idx], n_neighbors=num_recommendations+1)
        content_recommendations = [highly_rated_data.iloc[i]['ISBN'] for i in indices.flatten()[1:]]
       
    else:
        content_recommendations= []

    # Collaborative filtering recommendations
    if user_id in user_item_matrix.index:
        user_idx = list(user_item_matrix.index).index(user_id)
        _, indices = knn.kneighbors(user_item_matrix.iloc[user_idx, :].values.reshape(1, -1), n_neighbors=num_recommendations+1)
        collaborative_recommendations = [user_item_matrix.index[indices.flatten()[i]] for i in range(1, num_recommendations+1)]
        # Prepare the list of recommended books with title, year, and author
        

    else:
        collaborative_recommendations = []

    # Combine recommendations, prioritizing content-based
    recommendations = content_recommendations + [collaborative_recommendations for collaborative_recommendations in collaborative_recommendations if collaborative_recommendations not in content_recommendations]
    recommended_books = []
    for rec in recommendations[:num_recommendations]:
         book_info = book.iloc[rec[book[0]]]
         recommended_books.append({
             " Book Title": book_info['Book-Title'],
             "Year-Of-Publication": book_info.get('Year-Of-Publication', 'N/A'),  # Use 'N/A' if Year column is missing
             "Author": book_info.get('Book-Author', 'Unknown')  # Use 'Unknown' if Author column is missing
         })
     
# return recommended_books
    
    return recommended_books
    


# content_recommendations

# %%
# Testing the revised function
example_recommendations_v2 = hybrid_recommend_v2(user_id=277427, isbn='1880837927', num_recommendations=6)
example_recommendations_v2

# %%
example_recommendations_v2 = hybrid_recommend_v2(user_id=276755, isbn='', num_recommendations=6)
example_recommendations_v2

# %%
book.info()
